# %%
import requests
import json


#https://console.cloud.google.com/google/maps-apis/api-list?project=where2play-484417
API_KEY = "AIzaSyDX5IKdkxVwPo4pXxKitRcJNTOVtZhqQKI"


# def search_place_new(query):
def search_place_new(query, lat=None, lon=None, radius_m=5000):
    url = "https://places.googleapis.com/v1/places:searchText"

    headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key": API_KEY,
        "X-Goog-FieldMask": (
            "places.id,"
            "places.displayName,"
            "places.formattedAddress,"
            "places.googleMapsUri"
        )
    }

    payload = {
        "textQuery": query
    }

    # Optional location bias
    if lat is not None and lon is not None:
        payload["locationBias"] = {
            "circle": {
                "center": {
                    "latitude": lat,
                    "longitude": lon
                },
                "radius": radius_m
            }
        }

    r = requests.post(url, headers=headers, json=payload)
    r.raise_for_status()

    data = r.json()
    print(json.dumps(data, indent=2))
    return data

# %%
data = search_place_new(
    "Milton Public Library dsfasf",
    lat=41.0217,
    lon=-76.8477,
    radius_m=3000
)
# Out:
# {
#   "places": [
#     {
#       "id": "ChIJb4UkyG4Nz4kR7GLOu_rlZ4M",
#       "formattedAddress": "541 Broadway St, Milton, PA 17847, USA",
#       "googleMapsUri": "https://maps.google.com/?cid=9468789606625207020&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#       "displayName": {
#         "text": "Milton Public Library",
#         "languageCode": "en"
#       }
#     }
#   ]
# }

# %%
def get_place_details_new(place_id):
    url = f"https://places.googleapis.com/v1/places/{place_id}"
    
    headers = {
        "X-Goog-Api-Key": API_KEY,
        "X-Goog-FieldMask": (
            "id,"
            "displayName,"
            "websiteUri,"
            "googleMapsUri,"
            "formattedAddress,"
            "types"
        )
    }

    r = requests.get(url, headers=headers)
    r.raise_for_status()

    return r.json()

# %%
data = search_place_new("Milton Public Library Pennsylvania")
place_id = data["places"][0]["id"]
# Out:
# {
#   "places": [
#     {
#       "id": "ChIJb4UkyG4Nz4kR7GLOu_rlZ4M",
#       "formattedAddress": "541 Broadway St, Milton, PA 17847, USA",
#       "googleMapsUri": "https://maps.google.com/?cid=9468789606625207020&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQAhgEIAA",
#       "displayName": {
#         "text": "Milton Public Library",
#         "languageCode": "en"
#       }
#     }
#   ]
# }

# %%
def get_place_details_new(place_id):
    url = f"https://places.googleapis.com/v1/places/{place_id}"

    headers = {
        "X-Goog-Api-Key": API_KEY,
        "X-Goog-FieldMask": (
            "id,"
            "displayName,"
            "websiteUri,"
            "googleMapsUri,"
            "formattedAddress,"
            "types"
        )
    }

    r = requests.get(url, headers=headers)
    r.raise_for_status()

    return r.json()

# %%
details = get_place_details_new(place_id)

print("Official website:", details.get("websiteUri"))
print("Google Maps URL:", details.get("googleMapsUri"))
# Out:
# Official website: https://miltonpalibrary.org/
# Google Maps URL: https://maps.google.com/?cid=9468789606625207020&g_mp=CiVnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLkdldFBsYWNlEAIYBCAA

# %%
results = search_place("Milton Public Library, PA")
# results


details = get_place_details_new(place_id)

print("Official website:", details.get("websiteUri"))
print("Google Maps URL:", details.get("googleMapsUri"))
# Out:
# {
#   "html_attributions": [],
#   "results": [
#     {
#       "business_status": "OPERATIONAL",
#       "formatted_address": "541 Broadway St, Milton, PA 17847, United States",
#       "geometry": {
#         "location": {
#           "lat": 41.0214612,
#           "lng": -76.8441509
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 41.02280322989272,
#             "lng": -76.84279992010727
#           },
#           "southwest": {
#             "lat": 41.02010357010727,
#             "lng": -76.84549957989272
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png",
#       "icon_background_color": "#7B9EB0",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet",
#       "name": "Milton Public Library",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 4032,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/105274835537432738539\">Bradley Young</a>"
#           ],
#           "photo_reference": "ATCDNfXIXtc9ultUetAofDoLCr0m8wR2eL7ggCe6qMBbHF899idKyAH6Rg2MaaHL6IRVJ7IUtAZa1m2fOePltni4QeVaoUJL_gH7paxdRU71O9xJY7EMUKKyGkI-BMGTjYWUSURf6OcZjyeCi5JTpzN7bkRaPI1XQhwU623aJ5jIjmGUv5QZsJaomHo2KwnS7Lrzn6xXFj_3dJcRoicxqWgADMSF1UnRxmV7nNF2oUNcz9GYDxs8YpH9_OtLH3ocovW1BOpsnbVfGDd1RqNymdeSvxn3Uqk1OkMy8sJtA425ukPjtDywBBJq4Ttjjoul2vQKwo6qVd2Yvagh0PaR3F7IlrKKaTy43WCiXW1ANrGiQ0REFwUu7YXI13rkZrOhY0BzlqFI3RPE-EUEeiEpyUfmT2hBKE-xpn6ES34alPVn681xi9wsewl_nB3DIqL7W8yGnMeEka5uvEbB-KaSMueJ7gpgm3egJHcF1TVdQdEIpHE530NRemxAPdMvmP_CiVW9d2fHqT52UpuMlim5hbWFWquMXFuzTUMreXaph-13B5u7rb1wJvz76jXI6k9KhuLg8wb8-Pbj",
#           "width": 3024
#         }
#       ],
#       "place_id": "ChIJb4UkyG4Nz4kR7GLOu_rlZ4M",
#       "rating": 4.7,
#       "reference": "ChIJb4UkyG4Nz4kR7GLOu_rlZ4M",
#       "types": [
#         "library",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 23
#     }
#   ],
#   "status": "OK"
# }
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '541 Broadway St, Milton, PA 17847, United States',
#    'geometry': {'location': {'lat': 41.0214612, 'lng': -76.8441509},
#     'viewport': {'northeast': {'lat': 41.02280322989272,
#       'lng': -76.84279992010727},
#      'southwest': {'lat': 41.02010357010727, 'lng': -76.84549957989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#    'name': 'Milton Public Library',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105274835537432738539">Bradley Young</a>'],
#      'photo_reference': 'ATCDNfXIXtc9ultUetAofDoLCr0m8wR2eL7ggCe6qMBbHF899idKyAH6Rg2MaaHL6IRVJ7IUtAZa1m2fOePltni4QeVaoUJL_gH7paxdRU71O9xJY7EMUKKyGkI-BMGTjYWUSURf6OcZjyeCi5JTpzN7bkRaPI1XQhwU623aJ5jIjmGUv5QZsJaomHo2KwnS7Lrzn6xXFj_3dJcRoicxqWgADMSF1UnRxmV7nNF2oUNcz9GYDxs8YpH9_OtLH3ocovW1BOpsnbVfGDd1RqNymdeSvxn3Uqk1OkMy8sJtA425ukPjtDywBBJq4Ttjjoul2vQKwo6qVd2Yvagh0PaR3F7IlrKKaTy43WCiXW1ANrGiQ0REFwUu7YXI13rkZrOhY0BzlqFI3RPE-EUEeiEpyUfmT2hBKE-xpn6ES34alPVn681xi9wsewl_nB3DIqL7W8yGnMeEka5uvEbB-KaSMueJ7gpgm3egJHcF1TVdQdEIpHE530NRemxAPdMvmP_CiVW9d2fHqT52UpuMlim5hbWFWquMXFuzTUMreXaph-13B5u7rb1wJvz76jXI6k9KhuLg8wb8-Pbj',
#      'width': 3024}],
#    'place_id': 'ChIJb4UkyG4Nz4kR7GLOu_rlZ4M',
#    'rating': 4.7,
#    'reference': 'ChIJb4UkyG4Nz4kR7GLOu_rlZ4M',
#    'types': ['library', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 23}],
#  'status': 'OK'}

# %%
results
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '541 Broadway St, Milton, PA 17847, United States',
#    'geometry': {'location': {'lat': 41.0214612, 'lng': -76.8441509},
#     'viewport': {'northeast': {'lat': 41.02280322989272,
#       'lng': -76.84279992010727},
#      'southwest': {'lat': 41.02010357010727, 'lng': -76.84549957989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#    'icon_background_color': '#7B9EB0',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#    'name': 'Milton Public Library',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105274835537432738539">Bradley Young</a>'],
#      'photo_reference': 'ATCDNfX1bcwWs6VKxw6ECsguJSYz4U6O_nEJq5s4QIDfrIMC1etXa5dFPCjunbVKXXfpNBmUEGR6oCBvLtzryRsd7_ALTKRntLuGaQ-gXbwx45ywDl4nClNhWeuyoN0bQbZvvIaiJFNKeKRq4u-MOEhjIHzgxLQNAWphd85xPFXp2rn31yoocDRh2s4K97g_l0rR0FFTiUXC4IGmB8qbHh6gnhOcJtg5q_s_seC2It3y3XVKca4bnsyyMjRm8gjHFzAagXCBYNnqsSw4g5I48oLHn4FLiJGf76kkp5ui-T2syu9UyEbNyANf8iPHxzxP07at82Y6Yf7_we_2gHTbAvirZjgpp625OpV6ueBtAeyzkAsFl8u7WwMymhjUQzVpcA5EuTRqMBUMnbixvYBBNqSzxmHtlaTtECwgUV0uHS_pYanxNHn9PtvFt9CUyqS7hsNDHzaVqVEq2l8JiPLK_97Ft4GjoSvr9Ipwp5TeLedb4VO9YL9HEu93aQAv7NkRPAbmDear_KyU7qtqtgJ6XjqBwUVS6pmrckij8Zj9VQPec30Cx0AJGFxbzRKYSNB5XCp-1dXbdmkx',
#      'width': 3024}],
#    'place_id': 'ChIJb4UkyG4Nz4kR7GLOu_rlZ4M',
#    'rating': 4.7,
#    'reference': 'ChIJb4UkyG4Nz4kR7GLOu_rlZ4M',
#    'types': ['library', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 23}],
#  'status': 'OK'}

# %%
results = search_place("Belmont Hills Library")
results
# Out:
# {
#   "error_message": "You\u2019re calling a legacy API, which is not enabled for your project. To get newer features and more functionality, switch to the Places API (New) or Routes API. Learn more: https://developers.google.com/maps/legacy#LegacyApiNotActivatedMapError",
#   "html_attributions": [],
#   "results": [],
#   "status": "REQUEST_DENIED"
# }
# {'error_message': 'You’re calling a legacy API, which is not enabled for your project. To get newer features and more functionality, switch to the Places API (New) or Routes API. Learn more: https://developers.google.com/maps/legacy#LegacyApiNotActivatedMapError',
#  'html_attributions': [],
#  'results': [],
#  'status': 'REQUEST_DENIED'}
